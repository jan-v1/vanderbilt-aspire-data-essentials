# %%
import pandas as pd

# %%
hospice_df = pd.read_csv('data/Hospice_General_Information.csv')
hospice_df.head(2)
# Out:
#    CMS Certification Number (CCN)                          Facility Name  \
# 0                           11500                        BAPTIST HOSPICE
# 1                           11501  SOUTHERNCARE NEW BEACON N. BIRMINGHAM
#
#                  Address Line 1  Address Line 2        City State  Zip Code  \
# 0           301 INTERSTATE PARK             NaN  MONTGOMERY    AL     36109
# 1  4735 NORREL DRIVE, SUITE 129             NaN  TRUSSVILLE    AL     35173
#
#   County Name     PhoneNumber  CMS Region Ownership Type Certification Date
# 0  Montgomery  (334) 395-5000           4          Other         03/23/1984
# 1   Jefferson  (205) 939-8799           4     For-Profit         05/24/1984

# %%
hospice_df = hospice_df.loc[hospice_df.State == 'TN']
hospice_df.head(2)
# Out:
#       CMS Certification Number (CCN)               Facility Name  \
# 2889                          441501           ALIVE HOSPICE INC
# 2890                          441502  METHODIST ALLIANCE HOSPICE
#
#                          Address Line 1  Address Line 2       City State  \
# 2889                1718 PATTERSON ROAD             NaN  NASHVILLE    TN
# 2890  6400 SHELBY VIEW DRIVE, SUITE 101             NaN    MEMPHIS    TN
#
#       Zip Code County Name     PhoneNumber  CMS Region Ownership Type  \
# 2889     37203    Davidson  (615) 327-1085           4     Non-Profit
# 2890     38134      Shelby  (901) 516-1600           4     Non-Profit
#
#      Certification Date
# 2889         04/10/1984
# 2890         08/31/1984

# %%
# Facility Name, Address Line 1, City, State, County Name, CMS Region, Ownership Type, and Certification Date
hospice_df.columns = ['ccn', 'facility', 'addln1', 'addln2', 'city', 'state', 'zipcode', 'county', 'phone', 'cmsregion', 'ownershiptype', 'certificationdate']

# %%
hospice_df.drop(columns = ['ccn', 'addln2', 'zipcode', 'phone'])
# Out:
#                                                facility  \
# 2889                                  ALIVE HOSPICE INC
# 2890                         METHODIST ALLIANCE HOSPICE
# 2891                         HOSPICE OF CHATTANOOGA INC
# 2892                              AMEDISYS HOSPICE CARE
# 2893                 NORTHCREST HOME HEALTH AND HOSPICE
# 2894                   HOSPICE OF CUMBERLAND COUNTY INC
# 2895                                  HIGHPOINT HOSPICE
# 2896                          HOSPICE OF WEST TENNESSEE
# 2897                                    KINDRED HOSPICE
# 2898                        TENNOVA HOSPICE-CLARKSVILLE
# 2899                AMEDISYS HOSPICE AN ADVENTA COMPANY
# 2900                   BLOUNT MEMORIAL HOSPITAL HOSPICE
# 2901                      ASERACARE HOSPICE - NASHVILLE
# 2902                                   SUNCREST HOSPICE
# 2903            LINCOLN MEDICAL HOME HEALTH AND HOSPICE
# 2904               AMEDISYS HOSPICE, AN ADVENTA COMPANY
# ...

# %%
hospice_df.shape
# Out:
# (56, 12)

# %%
cancer_df = pd.read_csv('data/cancer_deaths.csv', skiprows=4, nrows=97)
print(cancer_df.head(2))
print(cancer_df.tail(2))
# Out:
#           County   FIPS Met Healthy People Objective of 161.4?  \
# 0      Tennessee  47999                                     No
# 1  United States      0                                     No
#
#    Age-Adjusted Death Rate - deaths per 100,000  \
# 0                                         185.4
# 1                                         163.5
#
#    Lower 95% Confidence Interval  Upper 95% Confidence Interval  \
# 0                          184.0                          186.8
# 1                          163.3                          163.7
#
#    Average Annual Count Recent Trend  Recent 5-Year Trend in Death Rates  \
# 0                 13933      falling                                -1.4
# 1                586354      falling                                -1.5
#
#    Lower 95% Confidence Interval.1  Upper 95% Confidence Interval.1
# 0                             -1.5                             -1.2
# 1                             -1.6                             -1.5
# ...

# %%
print(cancer_df.shape)
# Out:
# (97, 11)

# %%
cancer_df.columns
# Out:
# Index(['County', ' FIPS', 'Met Healthy People Objective of 161.4?',
#        'Age-Adjusted Death Rate - deaths per 100,000',
#        'Lower 95% Confidence Interval', 'Upper 95% Confidence Interval',
#        'Average Annual Count', 'Recent Trend',
#        'Recent 5-Year Trend in Death Rates', 'Lower 95% Confidence Interval.1',
#        'Upper 95% Confidence Interval.1'],
#       dtype='object')

# %%
# County, FIPS, Met Healthy People Objective of 161.4?, Age-Adjusted Death Rate - deaths per 100,000, Lower 95% Confidence Interval, Upper 95% Confidence Interval, Average Annual Count, Recent Trend, Recent 5-Year Trend in Death Rates, Lower 95% Confidence Interval.1, Upper 95% Confidence Interval.1
cancer_df.columns = ['county', 'fips', 'methealthypeopleobjective', 'ageadjusteddeathrate', 'lower95percentci', 'upper95percentci', 'averageannualcount', 'recenttrend', 'recent5yrtrendindeathrates', 'lower95percentci1', 'upper95percentci1']

# %%
cancer_df.columns
# Out:
# Index(['county', 'fips', 'methealthypeopleobjective', 'ageadjusteddeathrate',
#        'lower95percentci', 'upper95percentci', 'averageannualcount',
#        'recenttrend', 'recent5yrtrendindeathrates', 'lower95percentci1',
#        'upper95percentci1'],
#       dtype='object')

# %%
pop_df = pd.read_csv('data/PEP_2017_PEPAGESEX.csv')
print(pop_df.head(2))
print(pop_df.tail(2))
# Out:
#            GEO.id GEO.id2           GEO.display-label  \
# 0              Id     Id2                   Geography
# 1  0500000US47001   47001  Anderson County, Tennessee
#
#                           cen42010sex0_age999  \
# 0  April 1, 2010 - Census - Both Sexes; Total
# 1                                       75129
#
#                     cen42010sex1_age999  \
# 0  April 1, 2010 - Census - Male; Total
# 1                                 36308
#
#                       cen42010sex2_age999  \
# 0  April 1, 2010 - Census - Female; Total
# 1                                   38821
#
#                                  est42010sex0_age999  \
# 0  April 1, 2010 - Estimates Base - Both Sexes; T...
# 1                                              75094
#
#                             est42010sex1_age999  \
# 0  April 1, 2010 - Estimates Base - Male; Total
# 1                                         36288
#
#                               est42010sex2_age999  \
# ...

# %%
print(pop_df.shape)
# Out:
# (96, 993)
